# %%
import pandas as pd

# %%
practice = pd.DataFrame({'날짜':[],'운동':[],'횟수':[]})
practice
# Out:
# Empty DataFrame
# Columns: [날짜, 운동, 횟수]
# Index: []

# %%
practice.loc[0]=['21.3.1', '걷기',4]
practice.loc[1]=['21.3.1', '달리기',2]
practice.loc[2]=['21.3.1', '숨쉬기',5]
practice.loc[3]=['21.3.2', '요가',6]
practice.loc[4]=['21.3.2', '달리기',1]
practice.loc[5]=['21.3.3', '요가',6]
practice.loc[6]=['21.3.3', '숨쉬기',1]
practice.loc[7]=['21.3.3', '요가',6]
practice
# Out:
#        날짜   운동   횟수
# 0  21.3.1   걷기  4.0
# 1  21.3.1  달리기  2.0
# 2  21.3.1  숨쉬기  5.0
# 3  21.3.2   요가  6.0
# 4  21.3.2  달리기  1.0
# 5  21.3.3   요가  6.0
# 6  21.3.3  숨쉬기  1.0
# 7  21.3.3   요가  6.0

# %%
practice.to_csv("./data/ppractice.csv", encoding='utf-8')

# %%
pd.read_csv("./data/ppractice.csv", encoding='utf-8')
# Out:
#    Unnamed: 0      날짜   운동   횟수
# 0           0  21.3.1   걷기  4.0
# 1           1  21.3.1  달리기  2.0
# 2           2  21.3.1  숨쉬기  5.0
# 3           3  21.3.2   요가  6.0
# 4           4  21.3.2  달리기  1.0
# 5           5  21.3.3   요가  6.0
# 6           6  21.3.3  숨쉬기  1.0
# 7           7  21.3.3   요가  6.0

# %%
pd.read_csv("./data/ppractice.csv", encoding='utf-8', index_col=0)
# Out:
#        날짜   운동   횟수
# 0  21.3.1   걷기  4.0
# 1  21.3.1  달리기  2.0
# 2  21.3.1  숨쉬기  5.0
# 3  21.3.2   요가  6.0
# 4  21.3.2  달리기  1.0
# 5  21.3.3   요가  6.0
# 6  21.3.3  숨쉬기  1.0
# 7  21.3.3   요가  6.0

# %%
practice.pivot_table(index='운동')
# Out:
#       횟수
# 운동
# 걷기   4.0
# 달리기  1.5
# 숨쉬기  3.0
# 요가   6.0

# %%
import numpy as np
practice.pivot_table(index='운동', aggfunc=np.sum)
# Out:
#        횟수
# 운동
# 걷기    4.0
# 달리기   3.0
# 숨쉬기   6.0
# 요가   18.0

# %%
practice.pivot_table(index='운동', aggfunc=[np.sum, len])
# Out:
#       sum len
#        횟수  날짜 횟수
# 운동
# 걷기    4.0   1  1
# 달리기   3.0   2  2
# 숨쉬기   6.0   2  2
# 요가   18.0   3  3

# %%
practice.pivot('날짜', '운동', '횟수')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12348/179963966.py in <module>
# ----> 1 practice.pivot('날짜', '운동', '횟수')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
# ...
