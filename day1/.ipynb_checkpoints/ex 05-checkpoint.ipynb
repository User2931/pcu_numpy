# %%
import pandas as pd

# %%
not_do = pd.read_excel("./data/reason00.xls")

# %%
not_do.head()
# Out:
#      기간  대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0  2019  서울시  서울시               46.8               5.0               4.3
# 1  2019   성별   남자               52.4               4.4               4.9
# 2  2019   성별   여자               42.5               5.6               3.9
# 3  2019  연령별  10대               55.3               4.8               3.9
# 4  2019  연령별  20대               46.0               4.2               4.5
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0      37.3                5.2  1.4
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1

# %%
not_do.drop(columns='기간', inplace=True)

# %%
not_do.head()
# Out:
#    대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 0  서울시  서울시               46.8               5.0               4.3      37.3
# 1   성별   남자               52.4               4.4               4.9      32.4
# 2   성별   여자               42.5               5.6               3.9      41.0
# 3  연령별  10대               55.3               4.8               3.9      32.6
# 4  연령별  20대               46.0               4.2               4.5      38.8
#
#    운동을 할 충분한 비용이 없어서   기타
# 0                5.2  1.4
# 1                4.9  1.1
# 2                5.4  1.7
# 3                3.5    -
# 4                6.4  0.1

# %%
not_do.loc[0]
# Out:
# 대분류                   서울시
# 분류                    서울시
# 운동을 할 충분한 시간이 없어서    46.8
# 함께 운동을 할 사람이 없어서      5.0
# 운동을 할 만한 장소가 없어서      4.3
# 운동을 싫어해서             37.3
# 운동을 할 충분한 비용이 없어서     5.2
# 기타                    1.4
# Name: 0, dtype: object

# %%
not_do_ex = not_do[not_do['대분류']=='성별'].copy()
not_do_ex
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  성별  남자               52.4               4.4               4.9      32.4
# 2  성별  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
not_do_ex.drop(columns='대분류', inplace=True)
not_do_ex
# Out:
#    분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  남자               52.4               4.4               4.9      32.4
# 2  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
not_do_age = not_do[not_do['대분류']=='연령별'].copy()
not_do_age
# Out:
#    대분류      분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 3  연령별     10대               55.3               4.8               3.9
# 4  연령별     20대               46.0               4.2               4.5
# 5  연령별     30대               59.9               5.2               2.9
# 6  연령별     40대               54.1               3.9               2.9
# 7  연령별     50대               46.1               6.2               4.5
# 8  연령별  60대 이상               26.6               6.0               6.6
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1
# 5      27.3                4.5  0.2
# 6      35.5                3.3  0.4
# 7      36.8                5.6  0.8
# 8      48.7                6.6  5.6

# %%
not_do_age.drop(columns='대분류', inplace=True)

# %%
not_do_age
# Out:
#         운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 10대                  55.3               4.8               3.9      32.6
# 20대                  46.0               4.2               4.5      38.8
# 30대                  59.9               5.2               2.9      27.3
# 40대                  54.1               3.9               2.9      35.5
# 50대                  46.1               6.2               4.5      36.8
# 60대 이상               26.6               6.0               6.6      48.7
#
#         운동을 할 충분한 비용이 없어서   기타
# 분류
# 10대                   3.5    -
# 20대                   6.4  0.1
# 30대                   4.5  0.2
# 40대                   3.3  0.4
# 50대                   5.6  0.8
# 60대 이상                6.6  5.6

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

# f_path="/System/Library/Fonts/Supplemental/Arial Unicode.ttf"
f_path="c:/windows/fonts/malgun.ttf"

font_name=font_manager.FontProperties(fname=f_path).get_name()
rc('font', family=font_name)

# %%
not_do_age.set_index('분류',drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15664/1435667958.py in <module>
# ----> 1 not_do_age.set_index('분류',drop=True, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['분류'] are in the columns"

# %%
not_do_age
# Out:
#         운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 10대                  55.3               4.8               3.9      32.6
# 20대                  46.0               4.2               4.5      38.8
# 30대                  59.9               5.2               2.9      27.3
# 40대                  54.1               3.9               2.9      35.5
# 50대                  46.1               6.2               4.5      36.8
# 60대 이상               26.6               6.0               6.6      48.7
#
#         운동을 할 충분한 비용이 없어서   기타
# 분류
# 10대                   3.5    -
# 20대                   6.4  0.1
# 30대                   4.5  0.2
# 40대                   3.3  0.4
# 50대                   5.6  0.8
# 60대 이상                6.6  5.6

# %%
fig, ax = plt.subplots(1,3, figsize=(16,8))

explode_setting=[0.02,0.02,0.02,0.02,0.02]

not_do_age['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0,0,0,0,0,0.02], ax=ax[0], autopct='%1.1f%%')
ax[0].set_title('운동을 할 충분한 시간이 없어서')
ax[0].set_ylabel('')


not_do_age['함께 운동을 할 사람이 없어서'].plot.pie(ax=ax[1], autopct='%1.1f%%')
ax[1].set_title('함께 운동을 할 사람이 없어서')
ax[1].set_ylabel('')

not_do_age['운동을 할 만한 장소가 없어서'].plot.pie(ax=ax[2], autopct='%1.1f%%')
ax[2].set_title('운동을 할 만한 장소가 없어서')
ax[2].set_ylabel('')

plt.show()
